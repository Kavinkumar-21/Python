# %% [markdown]
# # Extra Assignment-level-1

# %%
#print Statement 
#1.Output will be like this "HOPE AI"


print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input
#2.Output will be like this "Enter your institute name? : HOPE AI"

Buy_input=input("Enter your institute name? : ")
# Out:
# Enter your institute name? :  HOPE AI

# %%
#Buy inputs
''' 3.Output will be like this  Enter your name: Raj
Enter your age: 15
Enter your school name: Guru school
Enter your drgree: B.E CSE '''

#Logical-Code

Input_1 = input("Output will be like this  Enter your name: ")
Input_2 = int(input("Enter your age: "))
Input_3 = input("Enter your school name: ")
Input_4 = input("Enter your drgree: ")
# Out:
# Output will be like this  Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru school
# Enter your drgree:  B.E CSE

# %%
#Addition
'''4.Output will be like this 
a= 43
b= 34
add = 77'''

#Logical-Code

a=43
b=34
add=a+b
print("a= 43")
print("b= 34")
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
#Subtraction
'''5.Output will be like this 
a= 43
b= 34
sub = 77'''

#Logical-Code

a=43
b=34
sub=a-b
print("a= 43")
print("b= 34")
print("Sub=",sub)
# Out:
# a= 43
# b= 34
# Sub= 9

# %%
#Multiplication
'''6.Output will be like this 
a= 63
b= 97
Mul = 6111'''

#Logical-Code

a=63
b=97
Mul=a*b
print("a= 63")
print("b= 97")
print("Mul=",Mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
#Division
'''.Output will be like this 
a= 76
b= 31
Float Div = 2.4516129032258065'''

#Logical-Code

a=76
b=31
Float_Div=a/b
print("a= 76")
print("b= 31")
print("Float Div=",Float_Div)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
#Floor division
'''7.Output will be like this 
a= 76
b= 31
Floor Div = 2'''

#Logical-Code

a=76
b=31
Floor_Div=a//b
print("a= 76")
print("b= 31")
print("Floor Div=",Floor_Div)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
#Modulo
'''8.Output will be like this 
a= 76
b= 31
Floor Div = 2'''

#Logical-Code

a=76
b=31
Floor_Div=a//b
print("a= 76")
print("b= 31")
print("Floor Div=",Floor_Div)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
#Modulo
'''9.Output will be like this 
a= 76
b= 31
Modulo = 14'''

#Logical-Code

a=76
b=31
Modulo=a%b
print("a= 76")
print("b= 31")
print("Modulo =",Modulo)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
#Power
'''10.Output will be like this 
a= 4
b= 4
Power = 256'''

#Logical-Code

a=4
b=4
Power=a**b
print("a= 4")
print("b= 4")
print("Power =",Power)
# Out:
# a= 4
# b= 4
# Power = 256

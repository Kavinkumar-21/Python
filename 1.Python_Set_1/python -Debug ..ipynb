# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = 5   #b = "5" Actual variable is fixed
print(a + b)

#OUTPUT : Error  (Integer and String won't support when we use add operator)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b): #Extra Space is fixed
    return a + b

#Collen missing in def function end
#Extra space given starting of the function
#Not called the function with value

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# indentation fisrt
# then list have 3 indexs only [0-->1][1-->2][2-->3][3-->4]
# Out:
#   Cell In[13], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

#Parenthesis missing  print ("Hello, World!")

# %%
#6.Find the error in the following Python code:
x = 5 / 0

#dividing a number from 0 and we can see that it raises a ZeroDivisionError.
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

#Error  (Integer and String won't support when we use add operator)

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# The stepup value given as -1, the sequence will count backward, but our start value 1 is less than the stop value 10.This means the loop never starts, so nothing gets printed.

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

#We get error because initially we assigned x = 10, so if check x value in memory it will give 10.
# Out:
#   Cell In[26], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

#Collen missing in def function
#return function missing
